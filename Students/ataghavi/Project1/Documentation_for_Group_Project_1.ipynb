# %% [markdown]
# # ECEN 662 - Group Project 1
#
# Team Members:
#     Paul,
#     Austin,
#     Kiran

# %% [markdown]
# Problem : To find a hypotheis testing rule to distinguish betweeen Natural and computer generated scenery.

# %% [markdown]
# To formulate a binary hypothesis testing rule for the given datasets of images, the Red, Green and Blue Values of individual images are extracted for each image.
#
# Using these extracted values, the absolute value of difference in between these values for the adjacent pixels for each image is calculated.
#
# The average of the absolute differences over all pixels gives us the Average R,G,B values for an image.
#
# Now, by fitting these average values to a Normal distribution gives us the PDF Value for each of the images.The Mean and Variance are previously computed from the R,G,B values for each of the Datasets.
#
# The Hypothesis testing rule then turns out to be taking the likelihood ratio test, i.e.,
#
# LRT : Natural/Synthetic ratio  >||< = 1.
#
# Based on the Outcome of the likelihood ratio test, each image is classified as either Natural or Synthetic.
#
# The Error ratio in Classification, is then computed as (Total Number of Errors)/(Total Number of images classified).
# Approximately 1.17% of images are classified as errors for the given datasets.

# %% [markdown]
# # CODE:

# %% [markdown]
# Initialization

# %%
import os
from PIL import Image
import numpy as np
from scipy.stats import norm
import math

# %% [markdown]
# The following code initializes the Average Mean and Variances of R, G, B Values for Natural & Synthetic Datasets. These values are generated using the code in "RGB_Generator" File.

# %%
# For Natural Dataset
rrMean = 53.15403938967564 
rrVar = math.sqrt(246.05269767685047)

rgMean = 50.737244613894944
rgVar = math.sqrt(329.82268993567186)

rbMean = 50.01774071048172
rbVar = math.sqrt(414.33153810888246)

# For Synthetic Dataset
srMean = 90.17528609042893
srVar =math.sqrt(123.7829092340392)

sgMean = 91.18451186044291 
sgVar = math.sqrt(106.6295781882682)

sbMean = 89.7657733748568
sbVar = math.sqrt(88.610255607403872)


errors = 0.0
total = 0.0

# %% [markdown]
# Running the Hypothesis test on "Training Set Scenes Data" and computing errors

# %%
for filename in os.listdir('TrainingSetScenes'):
    print(filename)
    img = Image.open("TrainingSetScenes/" + filename).convert('RGB').resize((960,540), Image.ANTIALIAS)
    im = np.reshape(np.array(img.getdata()), [960, 540, 3])
    rval = 0.0
    gval = 0.0
    bval = 0.0
    for i in range(0,540):
        for j in range(0,960-1):
            rval += abs(im[j+1, i, 0] - im[j,i,0])
            gval += abs(im[j+1, i, 1] - im[j,i,1])
            bval += abs(im[j+1, i, 2] - im[j,i,2])
    rval *= (1.0/(540*960))
    gval *= (1.0/(540*960))
    bval *= (1.0/(540*960))
    lReal = norm.pdf(rval, rrMean, rrVar)*norm.pdf(gval, rgMean, rgVar)*norm.pdf(bval, rbMean, rbVar)
    print(lReal)
    lSynth = norm.pdf(rval, srMean, srVar)*norm.pdf(gval, sgMean, sgVar)*norm.pdf(bval, sbMean, sbVar)
    print(lSynth)
    if lSynth > lReal:
    	errors += 1.0
    	total += 1.0
    else:
    	total += 1.0
# Out:
# 1.jpg
# 6.52593976309e-06
# 7.1834710517e-21
# 2.jpg
# 7.75093880183e-06
# 2.95662638954e-11
# 3.jpg
# 1.0353840428e-05
# 7.51188835301e-14
# 1.01869540572e-06
# 1.48257394308e-29
# Strawberries.jpeg
# 3.41407930363e-06
# 5.46331589622e-09
# thumb_IMG_0648_1024 copy.jpg
# 4.73120479698e-06
# 2.15810472659e-10
# thumb_IMG_0983_1024.jpg
# 6.10325464982e-06
# 3.71592692642e-21
# thumb_IMG_1358_1024.jpg
# 7.02299332176e-07
# 1.67993834148e-31
# thumb_IMG_2606_1024.jpg
# 1.11443377324e-06
# 1.61410648373e-07
# wdw_2009-01-28_17-07-38.jpg
# 2.26656113463e-07
# 5.88791192213e-08
# wdw_2015-06-05_19-23-48.jpg
# 2.9656231385e-06
# 2.47981888258e-09
# wdw_2016-03-19_16-07-33.jpg
# 4.47293105694e-06
# 6.05069913338e-09
# wdw_2016-06-05_20-06-23.jpg
# 7.09801456371e-07
# 2.21598705683e-09
# wdw_2016-12-28_15-01-40.jpg
# 8.14171924757e-06
# 9.77759122734e-15

# %% [markdown]
# Running the Hypothesis test on "Training Set Synthetic Data" and computing errors

# %%
for filename in os.listdir('TrainingSetSynthetic'):
    print(filename)
    img = Image.open("TrainingSetSynthetic/" + filename).convert('RGB').resize((960,540), Image.ANTIALIAS)
    im = np.reshape(np.array(img.getdata()), [960, 540, 3])
    rval = 0.0
    gval = 0.0
    bval = 0.0
    for i in range(0,540):
        for j in range(0,960-1):
            rval += abs(im[j+1, i, 0] - im[j,i,0])
            gval += abs(im[j+1, i, 1] - im[j,i,1])
            bval += abs(im[j+1, i, 2] - im[j,i,2])
    rval *= (1.0/(540*960))
    gval *= (1.0/(540*960))
    bval *= (1.0/(540*960))
    #print(rval)
    lReal = norm.pdf(rval, rrMean, rrVar)*norm.pdf(gval, rgMean, rgVar)*norm.pdf(bval, rbMean, rbVar)
    print(lReal)
    lSynth = norm.pdf(rval, srMean, srVar)*norm.pdf(gval, sgMean, sgVar)*norm.pdf(bval, sbMean, sbVar)
    print(lSynth)
    if lSynth > lReal:
    	total += 1.0
    else:
    	errors += 1.0
    	total += 1.0
# Out:
# image1.jpg
# 4.07251676288e-07
# 3.45022834008e-06
# image1.png
# 3.33895655113e-07
# 8.52226108542e-06
# image10.png
# 3.66337592192e-09
# 1.21904193993e-05
# image10_spec.png
# 4.41633210306e-10
# 8.31177433881e-06
# image11.png
# 5.78024082912e-10
# 3.09877876565e-05
# image11_spec.png
# 1.14397684397e-10
# 1.1757628206e-05
# image12.png
# 7.7046642508e-08
# 2.81895185453e-05
# image12_spec.png
# 4.33031314356e-08
# 4.0411998633e-05
# image13.png
# 1.66878654334e-10
# 5.89566143428e-06
# image13_spec.png
# 4.17904448966e-12
# 4.27028618163e-07
# image14.png
# 1.2803261067e-08
# 2.17064639411e-05
# image14_spec.png
# 3.27202939725e-09
# 2.26116637885e-05
# image15.png
# 1.75462285813e-10
# 1.46499196623e-05
# image15_spec.png
# 6.49325270387e-11
# 8.29592689685e-06
# image16.png
# 3.95414670133e-08
# 3.39585741452e-05
# image16_spec.png
# 7.81982130924e-09
# 5.23946522091e-05
# image17.png
# 1.02129517823e-08
# 5.08693086331e-05
# image17_spec.png
# 1.28271687658e-08
# 4.28108501661e-05
# image18.png
# 4.01140034737e-07
# 4.97243368243e-06
# image18_spec.png
# 2.48619506454e-07
# 1.01873043999e-05
# image19.png
# 2.3528127832e-11
# 6.29231488503e-07
# image19_spec.png
# 5.212615407e-10
# 1.97914511367e-05
# image1_spec.jpg
# 8.42287024436e-08
# 1.4885786202e-05
# image1_spec.png
# 3.64001400726e-07
# 7.86303986533e-06
# image2.png
# 2.16957294841e-07
# 6.25138496838e-06
# image20.png
# 1.22131821547e-09
# 3.42670112231e-05
# image20_spec.png
# 9.62303144944e-10
# 3.56623528904e-05
# image21.png
# 2.48205480366e-08
# 4.09764156408e-05
# image21_spec.png
# 3.43799829611e-09
# 3.09090153907e-05
# image22.png
# 2.95771187097e-09
# 6.9764001929e-06
# image22_spec.png
# 1.98135139671e-09
# 2.0620904697e-05
# image23.png
# 1.04833966138e-07
# 1.89873296655e-05
# image23_spec.png
# 6.27827817244e-08
# 1.13647900183e-05
# image24.png
# 1.0751570649e-09
# 4.06800457724e-06
# image24_spec.png
# 8.32599622159e-10
# 1.03689529073e-05
# image25.png
# 4.0710181753e-08
# 1.87600881158e-05
# image25_spec.png
# 8.71393375987e-09
# 3.84533210285e-05
# image26.png
# 2.80909467283e-09
# 4.13855360022e-05
# image26_spec.png
# 1.49305642315e-09
# 4.30973221008e-05
# image27.png
# 1.59819511311e-07
# 1.71535907517e-05
# image27_spec.png
# 3.78900302267e-08
# 4.21096953227e-05
# image28.png
# 2.58110874468e-11
# 3.12184487708e-06
# image28_spec.png
# 4.0173577072e-12
# 5.52016599034e-07
# image29.png
# 2.42962219737e-10
# 1.96992263665e-05
# image29_spec.png
# 3.61985777937e-10
# 2.1020176907e-05
# image2_spec.png
# 5.56712615351e-08
# 2.4204644356e-05
# image3.png
# 7.97495685736e-09
# 2.72625471032e-05
# image30.png
# 6.39230557328e-08
# 2.89632161025e-05
# image30_spec.png
# 1.49803736028e-08
# 3.20029428166e-05
# image31.png
# 8.72410310978e-08
# 2.15098481058e-05
# image31_spec.png
# 4.19350579044e-08
# 3.60337503664e-05
# image32.png
# 7.85534838184e-11
# 1.17322744515e-05
# image32_spec.png
# 4.68426854356e-10
# 2.9512946103e-05
# image33.png
# 1.0345380707e-08
# 1.03083028089e-05
# image33_spec.png
# 7.20582942358e-10
# 1.10973512347e-05
# image34.png
# 4.06143360743e-08
# 3.4036357654e-05
# image34_spec.png
# 4.58837796567e-08
# 2.68349309988e-05
# image35.png
# 8.85114180974e-09
# 1.4642070456e-05
# image35_spec.png
# 2.61239502312e-09
# 2.70729962101e-05
# image36.png
# 1.19978033479e-11
# 1.78232235547e-06
# image36_spec.png
# 3.9204270995e-12
# 4.29581196591e-07
# image37.png
# 4.60627180592e-12
# 5.25279556538e-07
# image37_spec.png
# 1.66844684531e-12
# 2.37297081816e-07
# 2.20011007765e-07
# image5_spec.png
# 2.65970590586e-08
# 2.78883594533e-05
# image6.png
# 1.39484364012e-07
# 1.85984615082e-05
# image60.png
# 1.47139412235e-08
# 5.46113858546e-05
# image60_spec.png
# 4.6387892467e-09
# 5.65543168002e-05
# image61.png
# 2.22250120522e-08
# 3.41669716146e-05
# image61_spec.png
# 6.51570683086e-09
# 4.53418239097e-05
# image62.png
# 6.28134285013e-09
# 4.91524340282e-05
# image62_spec.png
# 1.56212748668e-09
# 4.06263284121e-05
# image63.png
# 7.2889514793e-08
# 8.81604123184e-06
# image63_spec.png
# 1.13202970562e-07
# 1.00453535437e-05
# image64.png
# 1.35620673564e-10
# 7.0560115452e-06
# image64_spec.png
# 6.80343941867e-12
# 1.0695138881e-06
# image65.png
# 2.56701941004e-16
# 6.55680110107e-11
# image65_spec.png
# 3.87450177396e-14
# 1.64731907521e-08
# image66.png
# 3.94306276682e-09
# 2.22818717859e-06
# image66_spec.png
# 4.15925806128e-10
# 2.10778207854e-06
# image67.png
# 3.0531263637e-08
# 1.9474532029e-05
# image67_spec.png
# 9.38662846905e-09
# 3.97526170302e-05
# image68.png
# 1.80976640023e-08
# 3.17106417628e-05
# image68_spec.png
# 8.68974309424e-09
# 5.39322224486e-05
# image69.png
# 8.36755566011e-09
# 2.59504021388e-05
# image69_spec.png
# 6.67089680693e-10
# 2.10760328904e-05
# image6_spec.png
# 2.04940467014e-08
# 5.08909380896e-05
# image7.png
# 4.06549417313e-08
# 1.85177269854e-05
# image70.png
# 2.09830097278e-07
# 7.6675562174e-06
# image70_spec.png
# 4.68521499017e-08
# 2.77265306435e-05
# image71.png
# 2.35040258291e-09
# 4.4404447603e-05
# image71_spec.png
# 2.5691346965e-10
# 1.41937577525e-05
# image72.png
# 2.14331758653e-07
# 1.38860105584e-05
# image72_spec.png
# 9.90663732987e-08
# 1.94288323769e-05
# image73.png
# 5.73600749325e-09
# 5.65884207512e-05
# image73_spec.png
# 8.33100744371e-10
# 3.24872947482e-05
# image74.png
# 6.205276264e-09
# 1.1614359092e-05
# image74_spec.png
# 4.72151809292e-09
# 1.20234741248e-05
# image75.png
# 1.36416645842e-08
# 4.64544519249e-05
# image75_spec.png
# 2.56263041277e-09
# 4.59242401731e-05
# image76.png
# 5.70324649933e-11
# 8.78425572895e-06
# image76_spec.png
# 2.31668247865e-11
# 4.36999960428e-06
# image77.png
# 8.93980914088e-10
# 3.58580736034e-05
# image77_spec.png
# 1.27204518839e-10
# 1.44210143664e-05
# image78.png
# 4.44488995672e-09
# 4.05312173723e-05
# image78_spec.png
# 4.13938176168e-10
# 2.5643738338e-05
# image79.png
# 4.57074878426e-08
# 4.07823995317e-05
# image79_spec.png
# 1.58953341194e-08
# 4.92711879131e-05
# image7_spec.png
# 6.30837234797e-09
# 1.88505158734e-05
# image8.png
# 2.56018080741e-08
# 2.96032266718e-05
# image80.png
# 1.08862790248e-07
# 1.67925455356e-05
# image80_spec.png
# 2.15575802284e-08
# 3.79386636279e-05
# image81.png
# 7.11624760797e-09
# 4.97982361174e-06
# image81_spec.png
# 1.06841080634e-09
# 2.04947219509e-05
# image82.png
# 3.02847438989e-10
# 2.46738307357e-05
# image82_spec.png
# 1.41748120137e-11
# 2.78122891383e-06
# image83.png
# 1.33310568382e-08
# 2.22613342929e-05
# image83_spec.png
# 1.71034909486e-09
# 2.9055376982e-05
# image84.png
# 4.29882032649e-08
# 2.12026887498e-05
# image84_spec.png
# 1.27443599111e-08
# 3.51459470889e-05
# image85.png
# 4.20713040923e-08
# 3.31348743422e-05
# image85_spec.png
# 1.69748143465e-08
# 4.72289364654e-05
# image86.png
# 8.38335629144e-09
# 1.44995970853e-05
# image86_spec.png
# 2.77552097443e-09
# 2.5375243717e-05
# image87.png
# 1.16849604747e-07
# 1.96817642217e-05
# image87_spec.png
# 1.3383192764e-08
# 4.30694231001e-05
# image88.png
# 4.25335327144e-11
# 1.44833105635e-06
# image88_spec.png
# 6.23868633427e-10
# 2.34743773584e-05
# image89.png
# 1.24845203868e-10
# 1.20756130395e-05
# image89_spec.png
# 8.35133066403e-11
# 6.36100921619e-06
# image8_spec.png
# 7.87572853057e-09
# 4.19647071518e-05
# image9.png
# 2.65618369627e-10
# 1.24661065206e-05
# image90.png
# 1.24177665587e-08
# 2.40663039883e-05
# image90_spec.png
# 1.63016883779e-09
# 2.30752626809e-05
# image91.png
# 1.07067560679e-08
# 5.3875473963e-05
# image91_spec.png
# 3.64923805034e-09
# 4.2798407993e-05
# image92.png
# 1.10475059034e-09
# 5.36177130653e-06
# image92_spec.png
# 1.27582960759e-09
# 1.47281603751e-05
# image93.png
# 5.73854732957e-11
# 4.32909939231e-06
# image93_spec.png
# 3.0832981097e-12
# 1.89692754626e-07
# image94.png
# 3.60780214345e-10
# 2.18117472022e-06
# image94_spec.png
# 5.48825282348e-11
# 1.57331400357e-06
# image95.png
# 2.10298287955e-07
# 6.95079742204e-06
# image95_spec.png
# 8.12049730542e-08
# 1.84892870503e-05
# image96.png
# 4.38824862806e-09
# 5.31740033983e-05
# image96_spec.png
# 1.22450358967e-09
# 3.84116520052e-05
# image97.png
# 9.37668785133e-08
# 1.10309579021e-05
# image97_spec.png
# 7.85162037573e-09
# 4.1559798413e-05
# image98.png
# 3.31383515778e-08
# 1.94879098327e-05
# image98_spec.png
# 9.34741031527e-09
# 2.98222248782e-05
# image99.png
# 1.55970054288e-08
# 4.6134539414e-05
# image99_spec.png
# 2.34290776051e-08
# 3.28147788584e-05
# image9_spec.png
# 3.2858934156e-10
# 2.46799145061e-05

# %% [markdown]
# Error Calculation:

# %%
# Total Number of Images (Scenery + Synthetic)
print(total)
# Out:
# 255.0

# %%
# Total Number of Errors
print(errors)
# Out:
# 3.0

# %% [markdown]
# Error Ratio:

# %%
# Error Ratio
print(errors/total)
# Out:
# 0.011764705882352941

# %%
# Error Percentage
print(errors*100/total)
# Out:
# 1.1764705882352942
